# %% [markdown]
# <a href="https://colab.research.google.com/github/lizaasara/business-analytics-with-python/blob/main/decisiontree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_excel('TTM.xlsx')

# %%
dataset
# Out:
#      Date       Open
# 0       1  20.299999
# 1       2  19.840000
# 2       3  19.459999
# 3       4  19.080000
# 4       5  18.799999
# ..    ...        ...
# 248   249  30.559999
# 249   250  30.430000
# 250   251  29.950001
# 251   252  30.219999
# 252   253  31.000000
#
# [253 rows x 2 columns]

# %%
x = dataset.iloc[:, :-1].values

# %%
y = dataset.iloc[:, -1].values

# %%
y = y.reshape(len(y),1)

# %%
from sklearn.svm import SVR
regressor = SVR()
regressor.fit(x, y)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR()

# %%
y_pred = regressor.predict(x)

# %%
plt.scatter(x, y, color = 'pink')
plt.plot(x, regressor.predict(x), color = 'red')
plt.xlabel('Package')
plt.ylabel('Sales')
plt.show()

# %%
regressor = SVR(kernel = 'rbf')
regressor.fit(x, y)
y_pred = regressor.predict(x)
plt.scatter(x, y, color = 'red')
plt.plot(x, regressor.predict(x), color = 'blue')
plt.xlabel('Package')
plt.ylabel('Sales')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
regressor = SVR(kernel = 'linear')
regressor.fit(x, y)
y_pred = regressor.predict(x)
plt.scatter(x, y, color = 'black')
plt.plot(x, regressor.predict(x), color = 'blue')
plt.xlabel('Package')
plt.ylabel('Sales')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
regressor = SVR(kernel = 'poly')
regressor.fit(x, y)
y_pred = regressor.predict(x)
plt.scatter(x, y, color = 'pink')
plt.plot(x, regressor.predict(x), color = 'blue')
plt.xlabel('Package')
plt.ylabel('Sales')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
regressor = SVR(kernel = 'rbf',C=1.0, epsilon=0.2)
regressor.fit(x, y)
y_pred = regressor.predict(x)
plt.scatter(x, y, color = 'silver')
plt.plot(x, regressor.predict(x), color = 'pink')
plt.xlabel('Package')
plt.ylabel('Sales')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
